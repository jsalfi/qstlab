# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

def plot_actual_spectrum():
    plt.figure(figsize=(8,5))

    f,II_den=signal.periodogram(current_i,fs=rs_acqu,window='flattop',scaling='density',return_onesided=True)
    plt.loglog(f,np.sqrt(II_den))
    plt.xlabel('f [Hz]')
    plt.ylabel('$\sqrt{S_{ii}(f)}\, (pA / \sqrt{Hz})$')
    plt.title('Actual spectrum')


def plot_time_averaged_spectrum():
    plt.figure(figsize=(8,5))

    f,II_den=signal.periodogram(i_desired,fs=rs_desired,window='flattop',scaling='density',return_onesided=True)
    plt.loglog(f, np.sqrt(II_den))
    plt.xlabel('f [Hz]')
    plt.ylabel('$\sqrt{S_{ii}(f)}\, (pA / \sqrt{Hz})$')
    plt.title('Spectrum of the time averaged signal')

Filename = 'dat5'    
data = np.genfromtxt('/Users/Measurement2/OneDrive/GroupShared/Data/QSim/20201202/'+Filename+'.dat',
                     skip_header=3,
                     skip_footer=0,
                     names=True,
                     dtype=None,
                     delimiter=',')
x = np.zeros(len(data))
y = np.zeros(len(data))
for i in range(len(data)):
    x[i] = data[i][0]
    y[i] = data[i][1]

    
rs_acqu = 1e6
rs_desired = 1e3
current_i = y
i_desired = y
plt.figure(figsize=(8,5))
plt.plot(x,y)
# plt.loglog(x,y)
# plt.xlabel('f[Hz]')
# plt.ylabel('S_{ii}(f)^{1/2} [A.Hz^{-1/2}]')
# plt.xlabel('Time (sec)')
# plt.ylabel('Current')
# plot_time_averaged_spectrum()

# %%
plt.plot(x,y)

# %%
plt.figure(figsize=(8,5))
plt.loglog(x,y)
plt.xlabel('f[Hz]')
plt.ylabel('S_{ii}(f)^{1/2} [A.Hz^{-1/2}]');

# %%
type(data)
# Out:
# numpy.ndarray

# %%
len(data)
# Out:
# 499

# %%
x = np.zeros(len(data))
y = np.zeros(len(data))
for i in range(len(data)):
    x[i] = data[i][0]
    y[i] = data[i][1]

# %%
rs_acqu = 1e6
rs_desired = 1e3
current_i = y
i_desired = y

# %%
def plot_actual_spectrum():
    plt.figure(figsize=(8,5))

    f,II_den=signal.periodogram(current_i,fs=rs_acqu,window='flattop',scaling='density',return_onesided=True)
    plt.loglog(f,np.sqrt(II_den))
    plt.xlabel('f [Hz]')
    plt.ylabel('$\sqrt{S_{ii}(f)}\, (pA / \sqrt{Hz})$')
    plt.title('Actual spectrum')


def plot_time_averaged_spectrum():
    plt.figure(figsize=(8,5))

    f,II_den=signal.periodogram(i_desired,fs=rs_desired,window='flattop',scaling='density',return_onesided=True)
    plt.loglog(f, np.sqrt(II_den))
    plt.xlabel('f [Hz]')
    plt.ylabel('$\sqrt{S_{ii}(f)}\, (pA / \sqrt{Hz})$')
    plt.title('Spectrum of the time averaged signal')

# %%
plt.plot(x,y)

# %%
from scipy import signal
plot_actual_spectrum()

# %%
plot_time_averaged_spectrum()
